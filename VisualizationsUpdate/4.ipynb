# %%
import geopandas as gpd
import pandas as pd
import folium

# %%
# loading in US census data
us_data_df = pd.read_csv('US_DATA.csv', low_memory=False)
us_data_df['NAME'] = us_data_df['NAME'].astype(str)

# %%
# Here's how I mapped the the columns with their aliases
# that are easier to understand and I could then pick which columns to select
us_columns_df = pd.read_csv('US_COLUMNS.csv', low_memory=False)
column_aliases = dict(zip(us_columns_df['Column Name'], us_columns_df['Label']))

print("Matched up:")
for col_name, label in list(column_aliases.items()):  
    print(f"{col_name}: {label}")
# Out:
# Matched up:
# GEO_ID: Geography
# NAME: Geographic Area Name
# DP1_0001C: Count!!SEX AND AGE!!Total population
# DP1_0002C: Count!!SEX AND AGE!!Total population!!Under 5 years
# DP1_0003C: Count!!SEX AND AGE!!Total population!!5 to 9 years
# DP1_0004C: Count!!SEX AND AGE!!Total population!!10 to 14 years
# DP1_0005C: Count!!SEX AND AGE!!Total population!!15 to 19 years
# DP1_0006C: Count!!SEX AND AGE!!Total population!!20 to 24 years
# DP1_0007C: Count!!SEX AND AGE!!Total population!!25 to 29 years
# DP1_0008C: Count!!SEX AND AGE!!Total population!!30 to 34 years
# DP1_0009C: Count!!SEX AND AGE!!Total population!!35 to 39 years
# DP1_0010C: Count!!SEX AND AGE!!Total population!!40 to 44 years
# DP1_0011C: Count!!SEX AND AGE!!Total population!!45 to 49 years
# DP1_0012C: Count!!SEX AND AGE!!Total population!!50 to 54 years
# DP1_0013C: Count!!SEX AND AGE!!Total population!!55 to 59 years
# DP1_0014C: Count!!SEX AND AGE!!Total population!!60 to 64 years
# DP1_0015C: Count!!SEX AND AGE!!Total population!!65 to 69 years
# DP1_0016C: Count!!SEX AND AGE!!Total population!!70 to 74 years
# DP1_0017C: Count!!SEX AND AGE!!Total population!!75 to 79 years
# DP1_0018C: Count!!SEX AND AGE!!Total population!!80 to 84 years
# DP1_0019C: Count!!SEX AND AGE!!Total population!!85 years and over
# DP1_0020C: Count!!SEX AND AGE!!Total population!!Selected Age Categories!!16 years and over
# DP1_0021C: Count!!SEX AND AGE!!Total population!!Selected Age Categories!!18 years and over
# DP1_0022C: Count!!SEX AND AGE!!Total population!!Selected Age Categories!!21 years and over
# DP1_0023C: Count!!SEX AND AGE!!Total population!!Selected Age Categories!!62 years and over
# DP1_0024C: Count!!SEX AND AGE!!Total population!!Selected Age Categories!!65 years and over
# DP1_0025C: Count!!SEX AND AGE!!Male population
# DP1_0026C: Count!!SEX AND AGE!!Male population!!Under 5 years
# DP1_0027C: Count!!SEX AND AGE!!Male population!!5 to 9 years
# DP1_0028C: Count!!SEX AND AGE!!Male population!!10 to 14 years
# DP1_0029C: Count!!SEX AND AGE!!Male population!!15 to 19 years
# DP1_0030C: Count!!SEX AND AGE!!Male population!!20 to 24 years
# DP1_0031C: Count!!SEX AND AGE!!Male population!!25 to 29 years
# DP1_0032C: Count!!SEX AND AGE!!Male population!!30 to 34 years
# DP1_0033C: Count!!SEX AND AGE!!Male population!!35 to 39 years
# DP1_0034C: Count!!SEX AND AGE!!Male population!!40 to 44 years
# DP1_0035C: Count!!SEX AND AGE!!Male population!!45 to 49 years
# DP1_0036C: Count!!SEX AND AGE!!Male population!!50 to 54 years
# DP1_0037C: Count!!SEX AND AGE!!Male population!!55 to 59 years
# DP1_0038C: Count!!SEX AND AGE!!Male population!!60 to 64 years
# DP1_0039C: Count!!SEX AND AGE!!Male population!!65 to 69 years
# DP1_0040C: Count!!SEX AND AGE!!Male population!!70 to 74 years
# DP1_0041C: Count!!SEX AND AGE!!Male population!!75 to 79 years
# DP1_0042C: Count!!SEX AND AGE!!Male population!!80 to 84 years
# DP1_0043C: Count!!SEX AND AGE!!Male population!!85 years and over
# DP1_0044C: Count!!SEX AND AGE!!Male population!!Selected Age Categories!!16 years and over
# DP1_0045C: Count!!SEX AND AGE!!Male population!!Selected Age Categories!!18 years and over
# DP1_0046C: Count!!SEX AND AGE!!Male population!!Selected Age Categories!!21 years and over
# DP1_0047C: Count!!SEX AND AGE!!Male population!!Selected Age Categories!!62 years and over
# DP1_0048C: Count!!SEX AND AGE!!Male population!!Selected Age Categories!!65 years and over
# DP1_0049C: Count!!SEX AND AGE!!Female population
# DP1_0050C: Count!!SEX AND AGE!!Female population!!Under 5 years
# DP1_0051C: Count!!SEX AND AGE!!Female population!!5 to 9 years
# DP1_0052C: Count!!SEX AND AGE!!Female population!!10 to 14 years
# DP1_0053C: Count!!SEX AND AGE!!Female population!!15 to 19 years
# DP1_0054C: Count!!SEX AND AGE!!Female population!!20 to 24 years
# DP1_0055C: Count!!SEX AND AGE!!Female population!!25 to 29 years
# DP1_0056C: Count!!SEX AND AGE!!Female population!!30 to 34 years
# DP1_0057C: Count!!SEX AND AGE!!Female population!!35 to 39 years
# DP1_0058C: Count!!SEX AND AGE!!Female population!!40 to 44 years
# DP1_0059C: Count!!SEX AND AGE!!Female population!!45 to 49 years
# DP1_0060C: Count!!SEX AND AGE!!Female population!!50 to 54 years
# DP1_0061C: Count!!SEX AND AGE!!Female population!!55 to 59 years
# DP1_0062C: Count!!SEX AND AGE!!Female population!!60 to 64 years
# DP1_0063C: Count!!SEX AND AGE!!Female population!!65 to 69 years
# DP1_0064C: Count!!SEX AND AGE!!Female population!!70 to 74 years
# DP1_0065C: Count!!SEX AND AGE!!Female population!!75 to 79 years
# DP1_0066C: Count!!SEX AND AGE!!Female population!!80 to 84 years
# DP1_0067C: Count!!SEX AND AGE!!Female population!!85 years and over
# DP1_0068C: Count!!SEX AND AGE!!Female population!!Selected Age Categories!!16 years and over
# DP1_0069C: Count!!SEX AND AGE!!Female population!!Selected Age Categories!!18 years and over
# DP1_0070C: Count!!SEX AND AGE!!Female population!!Selected Age Categories!!21 years and over
# DP1_0071C: Count!!SEX AND AGE!!Female population!!Selected Age Categories!!62 years and over
# DP1_0072C: Count!!SEX AND AGE!!Female population!!Selected Age Categories!!65 years and over
# DP1_0073C: Count!!MEDIAN AGE BY SEX!!Both sexes
# DP1_0074C: Count!!MEDIAN AGE BY SEX!!Male
# DP1_0075C: Count!!MEDIAN AGE BY SEX!!Female
# DP1_0076C: Count!!RACE!!Total population
# DP1_0077C: Count!!RACE!!Total population!!One Race
# DP1_0078C: Count!!RACE!!Total population!!One Race!!White
# DP1_0079C: Count!!RACE!!Total population!!One Race!!Black or African American
# DP1_0080C: Count!!RACE!!Total population!!One Race!!American Indian and Alaska Native
# DP1_0081C: Count!!RACE!!Total population!!One Race!!Asian
# DP1_0082C: Count!!RACE!!Total population!!One Race!!Native Hawaiian and Other Pacific Islander
# DP1_0083C: Count!!RACE!!Total population!!One Race!!Some Other Race
# DP1_0084C: Count!!RACE!!Total population!!Two or More Races
# DP1_0085C: Count!!TOTAL RACES TALLIED [1]!!Total races tallied
# DP1_0086C: Count!!TOTAL RACES TALLIED [1]!!Total races tallied!!White alone or in combination with one or more other races
# DP1_0087C: Count!!TOTAL RACES TALLIED [1]!!Total races tallied!!Black or African American alone or in combination with one or more other races
# DP1_0088C: Count!!TOTAL RACES TALLIED [1]!!Total races tallied!!American Indian and Alaska Native alone or in combination with one or more other races
# DP1_0089C: Count!!TOTAL RACES TALLIED [1]!!Total races tallied!!Asian alone or in combination with one or more other races
# DP1_0090C: Count!!TOTAL RACES TALLIED [1]!!Total races tallied!!Native Hawaiian and Other Pacific Islander alone or in combination with one or more other races
# DP1_0091C: Count!!TOTAL RACES TALLIED [1]!!Total races tallied!!Some Other Race alone or in combination with one or more other races
# DP1_0092C: Count!!HISPANIC OR LATINO!!Total population
# DP1_0093C: Count!!HISPANIC OR LATINO!!Total population!!Hispanic or Latino (of any race)
# DP1_0094C: Count!!HISPANIC OR LATINO!!Total population!!Not Hispanic or Latino
# DP1_0095C: Count!!HISPANIC OR LATINO BY RACE!!Total population
# DP1_0096C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino
# DP1_0097C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!White alone
# DP1_0098C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Black or African American alone
# DP1_0099C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!American Indian and Alaska Native alone
# DP1_0100C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Asian alone
# DP1_0101C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone
# DP1_0102C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Some Other Race alone
# DP1_0103C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Two or More Races
# DP1_0104C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino
# DP1_0105C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!White alone
# DP1_0106C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Black or African American alone
# DP1_0107C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!American Indian and Alaska Native alone
# DP1_0108C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Asian alone
# DP1_0109C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone
# DP1_0110C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Some Other Race alone
# DP1_0111C: Count!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Two or More Races
# DP1_0112C: Count!!RELATIONSHIP!!Total population
# DP1_0113C: Count!!RELATIONSHIP!!Total population!!In households
# DP1_0114C: Count!!RELATIONSHIP!!Total population!!In households!!Householder
# DP1_0115C: Count!!RELATIONSHIP!!Total population!!In households!!Opposite-sex spouse
# DP1_0116C: Count!!RELATIONSHIP!!Total population!!In households!!Same-sex spouse
# DP1_0117C: Count!!RELATIONSHIP!!Total population!!In households!!Opposite-sex unmarried partner
# DP1_0118C: Count!!RELATIONSHIP!!Total population!!In households!!Same-sex unmarried partner
# DP1_0119C: Count!!RELATIONSHIP!!Total population!!In households!!Child [2]
# DP1_0120C: Count!!RELATIONSHIP!!Total population!!In households!!Child [2]!!Under 18 years
# DP1_0121C: Count!!RELATIONSHIP!!Total population!!In households!!Grandchild
# DP1_0122C: Count!!RELATIONSHIP!!Total population!!In households!!Grandchild!!Under 18 years
# DP1_0123C: Count!!RELATIONSHIP!!Total population!!In households!!Other relatives
# DP1_0124C: Count!!RELATIONSHIP!!Total population!!In households!!Nonrelatives
# DP1_0125C: Count!!RELATIONSHIP!!Total population!!In group quarters
# DP1_0126C: Count!!RELATIONSHIP!!Total population!!In group quarters!!Institutionalized population:
# DP1_0127C: Count!!RELATIONSHIP!!Total population!!In group quarters!!Institutionalized population:!!Male
# DP1_0128C: Count!!RELATIONSHIP!!Total population!!In group quarters!!Institutionalized population:!!Female
# DP1_0129C: Count!!RELATIONSHIP!!Total population!!In group quarters!!Noninstitutionalized population:
# DP1_0130C: Count!!RELATIONSHIP!!Total population!!In group quarters!!Noninstitutionalized population:!!Male
# DP1_0131C: Count!!RELATIONSHIP!!Total population!!In group quarters!!Noninstitutionalized population:!!Female
# DP1_0132C: Count!!HOUSEHOLDS BY TYPE!!Total households
# DP1_0133C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household
# DP1_0134C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household!!With own children under 18 [3]
# DP1_0135C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household
# DP1_0136C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household!!With own children under 18 [3]
# DP1_0137C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:
# DP1_0138C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:!!Living alone
# DP1_0139C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:!!Living alone!!65 years and over
# DP1_0140C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:!!With own children under 18 [3]
# DP1_0141C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:
# DP1_0142C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:!!Living alone
# DP1_0143C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:!!Living alone!!65 years and over
# DP1_0144C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:!!With own children under 18 [3]
# DP1_0145C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Households with individuals under 18 years
# DP1_0146C: Count!!HOUSEHOLDS BY TYPE!!Total households!!Households with individuals 65 years and over
# DP1_0147C: Count!!HOUSING OCCUPANCY!!Total housing units
# DP1_0148C: Count!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units
# DP1_0149C: Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units
# DP1_0150C: Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!For rent
# DP1_0151C: Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!Rented, not occupied
# DP1_0152C: Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!For sale only
# DP1_0153C: Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!Sold, not occupied
# DP1_0154C: Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!For seasonal, recreational, or occasional use
# DP1_0155C: Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!All other vacants
# DP1_0156C: Count!!VACANCY RATES!!Homeowner vacancy rate (percent) [4]
# DP1_0157C: Count!!VACANCY RATES!!Rental vacancy rate (percent) [5]
# DP1_0158C: Count!!HOUSING TENURE!!Occupied housing units
# DP1_0159C: Count!!HOUSING TENURE!!Occupied housing units!!Owner-occupied housing units
# DP1_0160C: Count!!HOUSING TENURE!!Occupied housing units!!Renter-occupied housing units
# DP1_0001P: Percent!!SEX AND AGE!!Total population
# DP1_0002P: Percent!!SEX AND AGE!!Total population!!Under 5 years
# DP1_0003P: Percent!!SEX AND AGE!!Total population!!5 to 9 years
# DP1_0004P: Percent!!SEX AND AGE!!Total population!!10 to 14 years
# DP1_0005P: Percent!!SEX AND AGE!!Total population!!15 to 19 years
# DP1_0006P: Percent!!SEX AND AGE!!Total population!!20 to 24 years
# DP1_0007P: Percent!!SEX AND AGE!!Total population!!25 to 29 years
# DP1_0008P: Percent!!SEX AND AGE!!Total population!!30 to 34 years
# DP1_0009P: Percent!!SEX AND AGE!!Total population!!35 to 39 years
# DP1_0010P: Percent!!SEX AND AGE!!Total population!!40 to 44 years
# DP1_0011P: Percent!!SEX AND AGE!!Total population!!45 to 49 years
# DP1_0012P: Percent!!SEX AND AGE!!Total population!!50 to 54 years
# DP1_0013P: Percent!!SEX AND AGE!!Total population!!55 to 59 years
# DP1_0014P: Percent!!SEX AND AGE!!Total population!!60 to 64 years
# DP1_0015P: Percent!!SEX AND AGE!!Total population!!65 to 69 years
# DP1_0016P: Percent!!SEX AND AGE!!Total population!!70 to 74 years
# DP1_0017P: Percent!!SEX AND AGE!!Total population!!75 to 79 years
# DP1_0018P: Percent!!SEX AND AGE!!Total population!!80 to 84 years
# DP1_0019P: Percent!!SEX AND AGE!!Total population!!85 years and over
# DP1_0020P: Percent!!SEX AND AGE!!Total population!!Selected Age Categories!!16 years and over
# DP1_0021P: Percent!!SEX AND AGE!!Total population!!Selected Age Categories!!18 years and over
# DP1_0022P: Percent!!SEX AND AGE!!Total population!!Selected Age Categories!!21 years and over
# DP1_0023P: Percent!!SEX AND AGE!!Total population!!Selected Age Categories!!62 years and over
# DP1_0024P: Percent!!SEX AND AGE!!Total population!!Selected Age Categories!!65 years and over
# DP1_0025P: Percent!!SEX AND AGE!!Male population
# DP1_0026P: Percent!!SEX AND AGE!!Male population!!Under 5 years
# DP1_0027P: Percent!!SEX AND AGE!!Male population!!5 to 9 years
# DP1_0028P: Percent!!SEX AND AGE!!Male population!!10 to 14 years
# DP1_0029P: Percent!!SEX AND AGE!!Male population!!15 to 19 years
# DP1_0030P: Percent!!SEX AND AGE!!Male population!!20 to 24 years
# DP1_0031P: Percent!!SEX AND AGE!!Male population!!25 to 29 years
# DP1_0032P: Percent!!SEX AND AGE!!Male population!!30 to 34 years
# DP1_0033P: Percent!!SEX AND AGE!!Male population!!35 to 39 years
# DP1_0034P: Percent!!SEX AND AGE!!Male population!!40 to 44 years
# DP1_0035P: Percent!!SEX AND AGE!!Male population!!45 to 49 years
# DP1_0036P: Percent!!SEX AND AGE!!Male population!!50 to 54 years
# DP1_0037P: Percent!!SEX AND AGE!!Male population!!55 to 59 years
# DP1_0038P: Percent!!SEX AND AGE!!Male population!!60 to 64 years
# DP1_0039P: Percent!!SEX AND AGE!!Male population!!65 to 69 years
# DP1_0040P: Percent!!SEX AND AGE!!Male population!!70 to 74 years
# DP1_0041P: Percent!!SEX AND AGE!!Male population!!75 to 79 years
# DP1_0042P: Percent!!SEX AND AGE!!Male population!!80 to 84 years
# DP1_0043P: Percent!!SEX AND AGE!!Male population!!85 years and over
# DP1_0044P: Percent!!SEX AND AGE!!Male population!!Selected Age Categories!!16 years and over
# DP1_0045P: Percent!!SEX AND AGE!!Male population!!Selected Age Categories!!18 years and over
# DP1_0046P: Percent!!SEX AND AGE!!Male population!!Selected Age Categories!!21 years and over
# DP1_0047P: Percent!!SEX AND AGE!!Male population!!Selected Age Categories!!62 years and over
# DP1_0048P: Percent!!SEX AND AGE!!Male population!!Selected Age Categories!!65 years and over
# DP1_0049P: Percent!!SEX AND AGE!!Female population
# DP1_0050P: Percent!!SEX AND AGE!!Female population!!Under 5 years
# DP1_0051P: Percent!!SEX AND AGE!!Female population!!5 to 9 years
# DP1_0052P: Percent!!SEX AND AGE!!Female population!!10 to 14 years
# DP1_0053P: Percent!!SEX AND AGE!!Female population!!15 to 19 years
# DP1_0054P: Percent!!SEX AND AGE!!Female population!!20 to 24 years
# DP1_0055P: Percent!!SEX AND AGE!!Female population!!25 to 29 years
# DP1_0056P: Percent!!SEX AND AGE!!Female population!!30 to 34 years
# DP1_0057P: Percent!!SEX AND AGE!!Female population!!35 to 39 years
# DP1_0058P: Percent!!SEX AND AGE!!Female population!!40 to 44 years
# DP1_0059P: Percent!!SEX AND AGE!!Female population!!45 to 49 years
# DP1_0060P: Percent!!SEX AND AGE!!Female population!!50 to 54 years
# DP1_0061P: Percent!!SEX AND AGE!!Female population!!55 to 59 years
# DP1_0062P: Percent!!SEX AND AGE!!Female population!!60 to 64 years
# DP1_0063P: Percent!!SEX AND AGE!!Female population!!65 to 69 years
# DP1_0064P: Percent!!SEX AND AGE!!Female population!!70 to 74 years
# DP1_0065P: Percent!!SEX AND AGE!!Female population!!75 to 79 years
# DP1_0066P: Percent!!SEX AND AGE!!Female population!!80 to 84 years
# DP1_0067P: Percent!!SEX AND AGE!!Female population!!85 years and over
# DP1_0068P: Percent!!SEX AND AGE!!Female population!!Selected Age Categories!!16 years and over
# DP1_0069P: Percent!!SEX AND AGE!!Female population!!Selected Age Categories!!18 years and over
# DP1_0070P: Percent!!SEX AND AGE!!Female population!!Selected Age Categories!!21 years and over
# DP1_0071P: Percent!!SEX AND AGE!!Female population!!Selected Age Categories!!62 years and over
# DP1_0072P: Percent!!SEX AND AGE!!Female population!!Selected Age Categories!!65 years and over
# DP1_0073P: Percent!!MEDIAN AGE BY SEX!!Both sexes
# DP1_0074P: Percent!!MEDIAN AGE BY SEX!!Male
# DP1_0075P: Percent!!MEDIAN AGE BY SEX!!Female
# DP1_0076P: Percent!!RACE!!Total population
# DP1_0077P: Percent!!RACE!!Total population!!One Race
# DP1_0078P: Percent!!RACE!!Total population!!One Race!!White
# DP1_0079P: Percent!!RACE!!Total population!!One Race!!Black or African American
# DP1_0080P: Percent!!RACE!!Total population!!One Race!!American Indian and Alaska Native
# DP1_0081P: Percent!!RACE!!Total population!!One Race!!Asian
# DP1_0082P: Percent!!RACE!!Total population!!One Race!!Native Hawaiian and Other Pacific Islander
# DP1_0083P: Percent!!RACE!!Total population!!One Race!!Some Other Race
# DP1_0084P: Percent!!RACE!!Total population!!Two or More Races
# DP1_0085P: Percent!!TOTAL RACES TALLIED [1]!!Total races tallied
# DP1_0086P: Percent!!TOTAL RACES TALLIED [1]!!Total races tallied!!White alone or in combination with one or more other races
# DP1_0087P: Percent!!TOTAL RACES TALLIED [1]!!Total races tallied!!Black or African American alone or in combination with one or more other races
# DP1_0088P: Percent!!TOTAL RACES TALLIED [1]!!Total races tallied!!American Indian and Alaska Native alone or in combination with one or more other races
# DP1_0089P: Percent!!TOTAL RACES TALLIED [1]!!Total races tallied!!Asian alone or in combination with one or more other races
# DP1_0090P: Percent!!TOTAL RACES TALLIED [1]!!Total races tallied!!Native Hawaiian and Other Pacific Islander alone or in combination with one or more other races
# DP1_0091P: Percent!!TOTAL RACES TALLIED [1]!!Total races tallied!!Some Other Race alone or in combination with one or more other races
# DP1_0092P: Percent!!HISPANIC OR LATINO!!Total population
# DP1_0093P: Percent!!HISPANIC OR LATINO!!Total population!!Hispanic or Latino (of any race)
# DP1_0094P: Percent!!HISPANIC OR LATINO!!Total population!!Not Hispanic or Latino
# DP1_0095P: Percent!!HISPANIC OR LATINO BY RACE!!Total population
# DP1_0096P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino
# DP1_0097P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!White alone
# DP1_0098P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Black or African American alone
# DP1_0099P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!American Indian and Alaska Native alone
# DP1_0100P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Asian alone
# DP1_0101P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone
# DP1_0102P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Some Other Race alone
# DP1_0103P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Hispanic or Latino!!Two or More Races
# DP1_0104P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino
# DP1_0105P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!White alone
# DP1_0106P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Black or African American alone
# DP1_0107P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!American Indian and Alaska Native alone
# DP1_0108P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Asian alone
# DP1_0109P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone
# DP1_0110P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Some Other Race alone
# DP1_0111P: Percent!!HISPANIC OR LATINO BY RACE!!Total population!!Not Hispanic or Latino!!Two or More Races
# DP1_0112P: Percent!!RELATIONSHIP!!Total population
# DP1_0113P: Percent!!RELATIONSHIP!!Total population!!In households
# DP1_0114P: Percent!!RELATIONSHIP!!Total population!!In households!!Householder
# DP1_0115P: Percent!!RELATIONSHIP!!Total population!!In households!!Opposite-sex spouse
# DP1_0116P: Percent!!RELATIONSHIP!!Total population!!In households!!Same-sex spouse
# DP1_0117P: Percent!!RELATIONSHIP!!Total population!!In households!!Opposite-sex unmarried partner
# DP1_0118P: Percent!!RELATIONSHIP!!Total population!!In households!!Same-sex unmarried partner
# DP1_0119P: Percent!!RELATIONSHIP!!Total population!!In households!!Child [2]
# DP1_0120P: Percent!!RELATIONSHIP!!Total population!!In households!!Child [2]!!Under 18 years
# DP1_0121P: Percent!!RELATIONSHIP!!Total population!!In households!!Grandchild
# DP1_0122P: Percent!!RELATIONSHIP!!Total population!!In households!!Grandchild!!Under 18 years
# DP1_0123P: Percent!!RELATIONSHIP!!Total population!!In households!!Other relatives
# DP1_0124P: Percent!!RELATIONSHIP!!Total population!!In households!!Nonrelatives
# DP1_0125P: Percent!!RELATIONSHIP!!Total population!!In group quarters
# DP1_0126P: Percent!!RELATIONSHIP!!Total population!!In group quarters!!Institutionalized population:
# DP1_0127P: Percent!!RELATIONSHIP!!Total population!!In group quarters!!Institutionalized population:!!Male
# DP1_0128P: Percent!!RELATIONSHIP!!Total population!!In group quarters!!Institutionalized population:!!Female
# DP1_0129P: Percent!!RELATIONSHIP!!Total population!!In group quarters!!Noninstitutionalized population:
# DP1_0130P: Percent!!RELATIONSHIP!!Total population!!In group quarters!!Noninstitutionalized population:!!Male
# DP1_0131P: Percent!!RELATIONSHIP!!Total population!!In group quarters!!Noninstitutionalized population:!!Female
# DP1_0132P: Percent!!HOUSEHOLDS BY TYPE!!Total households
# DP1_0133P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household
# DP1_0134P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household!!With own children under 18 [3]
# DP1_0135P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household
# DP1_0136P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household!!With own children under 18 [3]
# DP1_0137P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:
# DP1_0138P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:!!Living alone
# DP1_0139P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:!!Living alone!!65 years and over
# DP1_0140P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:!!With own children under 18 [3]
# DP1_0141P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:
# DP1_0142P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:!!Living alone
# DP1_0143P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:!!Living alone!!65 years and over
# DP1_0144P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:!!With own children under 18 [3]
# DP1_0145P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Households with individuals under 18 years
# DP1_0146P: Percent!!HOUSEHOLDS BY TYPE!!Total households!!Households with individuals 65 years and over
# DP1_0147P: Percent!!HOUSING OCCUPANCY!!Total housing units
# DP1_0148P: Percent!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units
# DP1_0149P: Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units
# DP1_0150P: Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!For rent
# DP1_0151P: Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!Rented, not occupied
# DP1_0152P: Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!For sale only
# DP1_0153P: Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!Sold, not occupied
# DP1_0154P: Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!For seasonal, recreational, or occasional use
# DP1_0155P: Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!All other vacants
# DP1_0156P: Percent!!VACANCY RATES!!Homeowner vacancy rate (percent) [4]
# DP1_0157P: Percent!!VACANCY RATES!!Rental vacancy rate (percent) [5]
# DP1_0158P: Percent!!HOUSING TENURE!!Occupied housing units
# DP1_0159P: Percent!!HOUSING TENURE!!Occupied housing units!!Owner-occupied housing units
# DP1_0160P: Percent!!HOUSING TENURE!!Occupied housing units!!Renter-occupied housing units

# %%
# loading in the shapefile
shapefile_path = 'tl_2023_us_county/tl_2023_us_county.shp'
gdf_counties = gpd.read_file(shapefile_path)

# %%
regions = {
    "North East": ['09', '23', '25', '33', '44', '50', '34', '36', '42'],
    "Midwest": ['17', '18', '26', '39', '55', '19', '20', '27', '29', '31', '38', '46'],
    "South Atlantic": ['10', '12', '13', '24', '37', '45', '51', '54','11'],
    "South Central":  ['01', '21', '28', '47', '05', '22', '40', '48'],
    "West": ['04', '08', '32', '35', '49', '02', '56', '06', '15', '41', '53','30', '16']
}

# Create separate DataFrames for each region
gdf_north_east = gdf_counties[gdf_counties['STATEFP'].isin(regions["North East"])]
gdf_midwest = gdf_counties[gdf_counties['STATEFP'].isin(regions["Midwest"])]
gdf_south_atlantic = gdf_counties[gdf_counties['STATEFP'].isin(regions["South Atlantic"])]
gdf_south_central = gdf_counties[gdf_counties['STATEFP'].isin(regions["South Central"])]
gdf_west = gdf_counties[gdf_counties['STATEFP'].isin(regions["West"])]

# Check the DataFrames
print(f"North East Counties: {gdf_north_east.shape[0]} counties")
print(f"Midwest Counties: {gdf_midwest.shape[0]} counties")
print(f"South Atlantic Counties: {gdf_south_atlantic.shape[0]} counties")
print(f"South Central Counties: {gdf_south_central.shape[0]} counties")
print(f"West Counties: {gdf_west.shape[0]} counties")

# Optionally save them as separate files (if needed)
gdf_north_east.to_file('north_east_counties.shp')
gdf_midwest.to_file('midwest_counties.shp')
gdf_south_atlantic.to_file('south_counties.shp')
gdf_south_central.to_file('south_counties.shp')
gdf_west.to_file('west_counties.shp')
# Out:
# North East Counties: 218 counties
# Midwest Counties: 1055 counties
# South Atlantic Counties: 588 counties
# South Central Counties: 834 counties
# West Counties: 449 counties

# %%
##################### NORTH EAST

# only keeping name, geoid, and geometry from the shapefile df
gdf_north_east = gdf_north_east[['NAME', 'GEOIDFQ', 'geometry']]
# renaming the name to NAME: 'County' to make it clearer when mapping
gdf_north_east = gdf_north_east.rename(columns={'NAME': 'County'})

# merging the dataframes on the GEOID
north_gdf_merged = gdf_north_east.merge(us_data_df, left_on='GEOIDFQ', right_on='GEO_ID', how='left')

# Renaming 'NAME_x' to 'County' and remove 'NAME_y' if it exists
north_gdf_merged = north_gdf_merged.rename(columns={'NAME_x': 'County'})
north_gdf_merged = north_gdf_merged.drop(columns=['NAME_y'], errors='ignore') 


##################### MIDWEST
gdf_midwest = gdf_midwest[['NAME', 'GEOIDFQ', 'geometry']]
gdf_midwest = gdf_midwest.rename(columns={'NAME': 'County'})
midwest_gdf_merged = gdf_midwest.merge(us_data_df, left_on='GEOIDFQ', right_on='GEO_ID', how='left')

midwest_gdf_merged = midwest_gdf_merged.rename(columns={'NAME_x': 'County'})
midwest_gdf_merged = midwest_gdf_merged.drop(columns=['NAME_y'], errors='ignore') 


##################### SOUTH ATLANTIC
gdf_south_atlantic = gdf_south_atlantic[['NAME', 'GEOIDFQ', 'geometry']]
gdf_south_atlantic = gdf_south_atlantic.rename(columns={'NAME': 'County'})
south_atlantic_gdf_merged = gdf_south_atlantic.merge(us_data_df, left_on='GEOIDFQ', right_on='GEO_ID', how='left')

south_atlantic_gdf_merged = south_atlantic_gdf_merged.rename(columns={'NAME_x': 'County'})
south_atlantic_gdf_merged = south_atlantic_gdf_merged.drop(columns=['NAME_y'], errors='ignore') 


##################### SOUTH CENTRAL
gdf_south_central = gdf_south_central[['NAME', 'GEOIDFQ', 'geometry']]
gdf_south_central = gdf_south_central.rename(columns={'NAME': 'County'})
south_central_gdf_merged = gdf_south_central.merge(us_data_df, left_on='GEOIDFQ', right_on='GEO_ID', how='left')

south_central_gdf_merged = south_central_gdf_merged.rename(columns={'NAME_x': 'County'})
south_central_gdf_merged = south_central_gdf_merged.drop(columns=['NAME_y'], errors='ignore') 

##################### MIDWEST
gdf_west = gdf_west[['NAME', 'GEOIDFQ', 'geometry']]
gdf_west = gdf_west.rename(columns={'NAME': 'County'})
west_gdf_merged = gdf_west.merge(us_data_df, left_on='GEOIDFQ', right_on='GEO_ID', how='left')

west_gdf_merged = west_gdf_merged.rename(columns={'NAME_x': 'County'})
west_gdf_merged = west_gdf_merged.drop(columns=['NAME_y'], errors='ignore')

# %%
selected_housing_occupancy = [
    'DP1_0148P', 'DP1_0149P', 'DP1_0150P', 'DP1_0151P', 'DP1_0152P', 
    'DP1_0153P', 'DP1_0154P', 'DP1_0155P'
]  

selected_sex_age = [
    'DP1_0002P', 'DP1_0003P', 'DP1_0004P', 'DP1_0005P', 'DP1_0006P', 
    'DP1_0007P', 'DP1_0008P', 'DP1_0009P', 'DP1_0010P', 'DP1_0011P', 
    'DP1_0012P', 'DP1_0013P', 'DP1_0014P', 'DP1_0015P', 'DP1_0016P', 
    'DP1_0017P', 'DP1_0018P', 'DP1_0019P', 'DP1_0020P', 'DP1_0021P', 
    'DP1_0022P', 'DP1_0023P', 'DP1_0024P'
]
selected_race = [
    'DP1_0078P', 'DP1_0079P', 'DP1_0080P', 'DP1_0081P', 
    'DP1_0082P', 'DP1_0083P', 'DP1_0084P', 'DP1_0096P'
]
selected_housing_tenure = ['DP1_0159P', 'DP1_0160P']

descriptions = us_data_df.loc[0]

def simplify_column_name(column_name):
    description = descriptions[column_name]
    if 'Percent!!' in description:
        parts = description.split('!!')
        return f"Percent {parts[-1]}"  # Return 'Percent' followed by the last part
    return column_name  # If it doesn't match, return the original name

# Apply simplification to the selected columns
simplified_selected_housing_occupancy = [simplify_column_name(col) for col in selected_housing_occupancy]
simplified_selected_sex_age = [simplify_column_name(col) for col in selected_sex_age]
simplified_selected_race = [simplify_column_name(col) for col in selected_race]
simplified_selected_housing_tenure = [simplify_column_name(col) for col in selected_housing_tenure]

# Print the simplified names for verification
#print("Simplified Housing Occupancy Names:", simplified_selected_housing_occupancy)
#print("Simplified Sex and Age Names:", simplified_selected_sex_age)
#print("Simplified Race Names:", simplified_selected_race)
#print("Simplified Housing Tenure Names:", simplified_selected_housing_tenure)

# %%
# converting all of them to floats (previously they are strings)
selected_columns = selected_housing_occupancy + selected_sex_age + selected_race + selected_housing_tenure

for col in selected_columns:
    north_gdf_merged[col] = pd.to_numeric(north_gdf_merged[col], errors='coerce').astype('float32')
    
# List of columns to keep and drop all others
columns_to_keep = ['County', 'GEOIDFQ', 'GEO_ID', 'NAME','geometry'] + selected_housing_occupancy + selected_sex_age + selected_race + selected_housing_tenure
north_gdf_merged = north_gdf_merged.drop(columns=[col for col in north_gdf_merged.columns if col not in columns_to_keep])

# Verify the result
#print(north_gdf_merged.head())
#print(north_gdf_merged.columns)

##################### MIDWEST
for col in selected_columns:
    midwest_gdf_merged[col] = pd.to_numeric(midwest_gdf_merged[col], errors='coerce').astype('float32')
columns_to_keep = ['County', 'NAME','geometry'] + selected_housing_occupancy + selected_sex_age + selected_race + selected_housing_tenure
midwest_gdf_merged = midwest_gdf_merged.drop(columns=[col for col in midwest_gdf_merged.columns if col not in columns_to_keep])

##################### SOUTH ATLANTIC
for col in selected_columns:
    south_atlantic_gdf_merged[col] = pd.to_numeric(south_atlantic_gdf_merged[col], errors='coerce').astype('float32')
columns_to_keep = ['County', 'NAME','geometry'] + selected_housing_occupancy + selected_sex_age + selected_race + selected_housing_tenure
south_atlantic_gdf_merged = south_atlantic_gdf_merged.drop(columns=[col for col in south_atlantic_gdf_merged.columns if col not in columns_to_keep])

##################### SOUTH CENTRAL
for col in selected_columns:
    south_central_gdf_merged[col] = pd.to_numeric(south_central_gdf_merged[col], errors='coerce').astype('float32')
columns_to_keep = ['County', 'NAME','geometry'] + selected_housing_occupancy + selected_sex_age + selected_race + selected_housing_tenure
south_central_gdf_merged = south_central_gdf_merged.drop(columns=[col for col in south_central_gdf_merged.columns if col not in columns_to_keep])

##################### WEST
for col in selected_columns:
    west_gdf_merged[col] = pd.to_numeric(west_gdf_merged[col], errors='coerce').astype('float32')
columns_to_keep = ['County', 'NAME','geometry'] + selected_housing_occupancy + selected_sex_age + selected_race + selected_housing_tenure
west_gdf_merged = west_gdf_merged.drop(columns=[col for col in west_gdf_merged.columns if col not in columns_to_keep])

# %%
# Function to define color logic for Housing Occupancy (or other categories)
def get_occupancy_color(occupancy_percentage):
    try:
        # Ensure it's a float, and handle NaN values gracefully
        if pd.isna(occupancy_percentage):
            return 'gray'  # Default color for NaN values
        occupancy_percentage = float(occupancy_percentage)  # Ensure it's a float
        if occupancy_percentage < 50:
            return 'red'  # Low occupancy
        elif occupancy_percentage < 75:
            return 'yellow'  # Moderate occupancy
        else:
            return 'green'  # High occupancy
    except ValueError:
        return 'gray'  # Default color for non-numeric or missing values
    

def get_age_color(age_percentage):
    try:
        # Ensure it's a float, and handle NaN values gracefully
        if pd.isna(age_percentage):
            return 'gray'  # Default color for NaN values
        age_percentage = float(age_percentage)  # Ensure it's a float
        if age_percentage < 20:
            return 'green'  # Low age group (example: younger population)
        elif age_percentage < 25:
            return 'yellow'  # Moderate age group
        else:
            return 'red'  # High age group (older population)
    except ValueError:
        return 'gray'  # Default color for non-numeric or missing values

# Function to define color logic for Race
def get_race_color(race_percentage):
    try:
        if pd.isna(race_percentage):
            return 'gray'  # Default color for NaN values
        race_percentage = float(race_percentage)
        if race_percentage > 85:
            return 'red'  # Example color for a race group
        elif race_percentage > 65:
            return 'yellow'
        else:
            return 'green'  # Example color for another race group
    except ValueError:
        return 'gray'  # Default color for non-numeric or missing values

    
# Function to define color logic for Housing Tenure
def get_tenure_color(tenure_percentage):
    try:
        if pd.isna(tenure_percentage):
            return 'gray'  # Default color for NaN values
        tenure_percentage = float(tenure_percentage)
        if tenure_percentage < 50:
            return 'red'  # Example for low homeownership
        elif tenure_percentage < 75:
            return 'yellow'  # Moderate homeownership
        else:
            return 'green'  # High homeownership
    except ValueError:
        return 'gray'  # Default color for non-numeric or missing values

# %%
north_gdf_merged['occupancy_color'] = north_gdf_merged['DP1_0148P'].apply(get_occupancy_color)
north_gdf_merged['age_color'] = north_gdf_merged['DP1_0023P'].apply(get_age_color)
north_gdf_merged['race_color'] = north_gdf_merged['DP1_0078P'].apply(get_race_color)
north_gdf_merged['tenure_color'] = north_gdf_merged['DP1_0159P'].apply(get_tenure_color)

midwest_gdf_merged['occupancy_color'] = midwest_gdf_merged['DP1_0148P'].apply(get_occupancy_color)
midwest_gdf_merged['age_color'] = midwest_gdf_merged['DP1_0023P'].apply(get_age_color)
midwest_gdf_merged['race_color'] = midwest_gdf_merged['DP1_0078P'].apply(get_race_color)
midwest_gdf_merged['tenure_color'] = midwest_gdf_merged['DP1_0159P'].apply(get_tenure_color)

south_atlantic_gdf_merged['occupancy_color'] = south_atlantic_gdf_merged['DP1_0148P'].apply(get_occupancy_color)
south_atlantic_gdf_merged['age_color'] = south_atlantic_gdf_merged['DP1_0023P'].apply(get_age_color)
south_atlantic_gdf_merged['race_color'] = south_atlantic_gdf_merged['DP1_0078P'].apply(get_race_color)
south_atlantic_gdf_merged['tenure_color'] = south_atlantic_gdf_merged['DP1_0159P'].apply(get_tenure_color)

south_central_gdf_merged['occupancy_color'] = south_central_gdf_merged['DP1_0148P'].apply(get_occupancy_color)
south_central_gdf_merged['age_color'] = south_central_gdf_merged['DP1_0023P'].apply(get_age_color)
south_central_gdf_merged['race_color'] = south_central_gdf_merged['DP1_0078P'].apply(get_race_color)
south_central_gdf_merged['tenure_color'] = south_central_gdf_merged['DP1_0159P'].apply(get_tenure_color)

west_gdf_merged['occupancy_color'] = west_gdf_merged['DP1_0148P'].apply(get_occupancy_color)
west_gdf_merged['age_color'] = west_gdf_merged['DP1_0023P'].apply(get_age_color)
west_gdf_merged['race_color'] = west_gdf_merged['DP1_0078P'].apply(get_race_color)
west_gdf_merged['tenure_color'] = west_gdf_merged['DP1_0159P'].apply(get_tenure_color)

# %%
# Function to add a layer to the map with the color column for styling
def add_layer(data, layer_name, columns, color_column, show=False):
    layer = folium.FeatureGroup(name=layer_name, show=show)
    tooltip = folium.GeoJsonTooltip(
        fields=['County'] + columns,
        aliases=['County:'] + [simplify_column_name(col) for col in columns],  
        localize=True
    )
    
    folium.GeoJson(
        data=data,
        tooltip=tooltip,
        style_function=lambda feature: {
            'fillColor': feature['properties'][color_column],  # Use the color column for styling
            'color': 'black',
            'weight': .7,
            'fillOpacity': .5,
        }
    ).add_to(layer)
    
    return layer

# %%
# NORTHEAST OCCUPANCY
m_occupancy = folium.Map(location=[41.2033, -73.0877], zoom_start=6)
m_occupancy.add_child(add_layer(north_gdf_merged, 'Housing Occupancy', selected_housing_occupancy, 'occupancy_color', show=True))
folium.LayerControl().add_to(m_occupancy)
m_occupancy.save('northeast_housing_occupancy_map.html')

# %%
# NORTHEAST AGE
m_age = folium.Map(location=[41.2033, -73.0877], zoom_start=6)
m_age.add_child(add_layer(north_gdf_merged, 'Age Group', selected_sex_age, 'age_color', show=True))
folium.LayerControl().add_to(m_age)
m_age.save('northeast_age_map.html')

# %%
# NORTHEAST RACE
m_race = folium.Map(location=[41.2033, -73.0877], zoom_start=6)
m_race.add_child(add_layer(north_gdf_merged, 'Race', selected_race, 'race_color', show=True))
folium.LayerControl().add_to(m_race)
m_race.save('northeast_race_map.html')

# %%
# NORTHEAST HOUSING TENURE
m_tenure = folium.Map(location=[41.2033, -73.0877], zoom_start=6)
m_tenure.add_child(add_layer(north_gdf_merged, 'Housing Tenure', selected_housing_tenure, 'tenure_color', show=True))
folium.LayerControl().add_to(m_tenure)
m_tenure.save('northeast_housing_tenure_map.html')

# %%
# MIDWEST OCCUPANCY
m_occupancy = folium.Map(location=[41.5932, -87.4071],zoom_start=5)
m_occupancy.add_child(add_layer(midwest_gdf_merged, 'Housing Occupancy', selected_housing_occupancy, 'occupancy_color', show=True))
folium.LayerControl().add_to(m_occupancy)
m_occupancy.save('midwest_housing_occupancy_map.html')

# %%
# MIDWEST AGE
m_age = folium.Map(location=[41.5932, -87.4071],zoom_start=5)
m_age.add_child(add_layer(midwest_gdf_merged, 'Age Group', selected_sex_age, 'age_color', show=True))
folium.LayerControl().add_to(m_age)
m_age.save('midwest_age_map.html')

# %%
# MIDWEST RACE
m_race = folium.Map(location=[41.5932, -87.4071],zoom_start=5)
m_race.add_child(add_layer(midwest_gdf_merged, 'Race', selected_race, 'race_color', show=True))
folium.LayerControl().add_to(m_race)
m_race.save('midwest_race_map.html')

# %%
# MIDWEST OCCUPANCY
m_tenure = folium.Map(location=[41.5932, -87.4071],zoom_start=5)
m_tenure.add_child(add_layer(midwest_gdf_merged, 'Housing Tenure', selected_housing_tenure, 'tenure_color', show=True))
folium.LayerControl().add_to(m_tenure)
m_tenure.save('midwest_housing_tenure_map.html')

# %%
# SOUTH ATLANTIC OCCUPANCY
m_occupancy = folium.Map(location=[33.7490, -84.3880], zoom_start=6) 
m_occupancy.add_child(add_layer(south_atlantic_gdf_merged, 'Housing Occupancy', selected_housing_occupancy, 'occupancy_color', show=True))
folium.LayerControl().add_to(m_occupancy)
m_occupancy.save('south_atlantic_housing_occupancy_map.html')

# %%
# SOUTH ATLANTIC AGE
m_age = folium.Map(location=[33.7490, -84.3880],zoom_start=5)
m_age.add_child(add_layer(south_atlantic_gdf_merged, 'Age Group', selected_sex_age, 'age_color', show=True))
folium.LayerControl().add_to(m_age)
m_age.save('south_atlantic_age_map.html')

# %%
# SOUTH ATLANTIC RACE
m_race = folium.Map(location=[33.7490, -84.3880],zoom_start=5)
m_race.add_child(add_layer(south_atlantic_gdf_merged, 'Race', selected_race, 'race_color', show=True))
folium.LayerControl().add_to(m_race)
m_race.save('south_atlantic_race_map.html')

# %%
# SOUTH ATLANTIC HOUSING TENURE
m_tenure = folium.Map(location=[33.7490, -84.3880],zoom_start=5)
m_tenure.add_child(add_layer(south_atlantic_gdf_merged, 'Housing Tenure', selected_housing_tenure, 'tenure_color', show=True))
folium.LayerControl().add_to(m_tenure)
m_tenure.save('south_atlantic_housing_tenure_map.html')

# %%
# SOUTH CENTRAL OCCUPANCY
m_occupancy = folium.Map(location=[31.9686, -99.9018], zoom_start=5) 
m_occupancy.add_child(add_layer(south_central_gdf_merged, 'Housing Occupancy', selected_housing_occupancy, 'occupancy_color', show=True))
folium.LayerControl().add_to(m_occupancy)
m_occupancy.save('south_central_housing_occupancy_map.html')

# %%
# SOUTH CENTRAL AGE
m_age = folium.Map(location=[31.9686, -99.9018],zoom_start=5)
m_age.add_child(add_layer(south_central_gdf_merged, 'Age Group', selected_sex_age, 'age_color', show=True))
folium.LayerControl().add_to(m_age)
m_age.save('south_central_age_map.html')

# %%
# SOUTH CENTRAL RACE
m_race = folium.Map(location=[31.9686, -99.9018],zoom_start=5)
m_race.add_child(add_layer(south_central_gdf_merged, 'Race', selected_race, 'race_color', show=True))
folium.LayerControl().add_to(m_race)
m_race.save('south_central_race_map.html')

# %%
# SOUTH CENTRAL HOUSING TENURE
m_tenure = folium.Map(location=[31.9686, -99.9018],zoom_start=5)
m_tenure.add_child(add_layer(south_central_gdf_merged, 'Housing Tenure', selected_housing_tenure, 'tenure_color', show=True))
folium.LayerControl().add_to(m_tenure)
m_tenure.save('south_central_housing_tenure_map.html')

# %%
# WEST OCCUPANCY
m_occupancy = folium.Map(location=[37.7749, -122.4194], zoom_start=6)
m_occupancy.add_child(add_layer(west_gdf_merged, 'Housing Occupancy', selected_housing_occupancy, 'occupancy_color', show=True))
folium.LayerControl().add_to(m_occupancy)
m_occupancy.save('west_housing_occupancy_map.html')

# %%
# WEST AGE
m_age = folium.Map(location=[37.7749, -122.4194],zoom_start=5)
m_age.add_child(add_layer(west_gdf_merged, 'Age Group', selected_sex_age, 'age_color', show=True))
folium.LayerControl().add_to(m_age)
m_age.save('west_age_map.html')

# %%
# WEST RACE
m_race = folium.Map(location=[37.7749, -122.41948],zoom_start=5)
m_race.add_child(add_layer(west_gdf_merged, 'Race', selected_race, 'race_color', show=True))
folium.LayerControl().add_to(m_race)
m_race.save('west_race_map.html')

# %%
# WEST HOUSING TENURE
m_tenure = folium.Map(location=[37.7749, -122.41948],zoom_start=5)
m_tenure.add_child(add_layer(west_gdf_merged, 'Housing Tenure', selected_housing_tenure, 'tenure_color', show=True))
folium.LayerControl().add_to(m_tenure)
m_tenure.save('west_housing_tenure_map.html')
